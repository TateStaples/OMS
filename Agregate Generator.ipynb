# %%
from openpyxl import load_workbook
import statistics

input_workbook = "/Users/akshar/Downloads/Humans in Autonomy/Aircraft Carrier Project/SensitivityAnalysisSpreadSheets/WeightCheckTime/WeightCheckTime10 Aircraft 9_1_-10%.xlsx"

wb = load_workbook(input_workbook)
sheets = []

for sheet in wb.worksheets:
    sheets.append(sheet)

# %%
def Average(lst):
    print ("AVERAGING", lst)
    try:
        print ("RETURNING", sum(lst) / len(lst))
        return sum(lst) / len(lst) 
    except:
        print (lst)
        
def lstConvert(lst):
    newlst = []
    for value in lst:
        newlst.append(float(value))
    return newlst

F18_Averages = []
E2_Averages = []
All_Averages = []
F18_StdDevs = []
E2_StdDevs = []
AC_to_Person_unexpected_violations = []
AC_to_AC_unexpected_violations = []
F18_Halo_Violations = []
E2_Halo_Violations = []
All_Brown_Halo_Violations = []
All_Blue_Halo_Violations = []
All_White_Halo_Violations = []
All_Green_Halo_Violations = []
All_Red_Halo_Violations = []
All_Purple_Halo_Violations = []
All_Yellow_Halo_Violations = []
Individual_F18_Times = []
Individual_E2_Times = []

for current_sheet in sheets[1:-1]:
    F18_Times = []
    E2_Times = []
    ac_to_person_violations = 0
    ac_to_ac_violations = 0
    F18_halo_violations = 0
    E2_halo_violations = 0
    Brown_Halo_Violations = 0
    Blue_Halo_Violations = 0
    White_Halo_Violations = 0
    Green_Halo_Violations = 0
    Red_Halo_Violations = 0
    Purple_Halo_Violations = 0
    Yellow_Halo_Violations = 0

    print ("currently on ", current_sheet)
    ws = current_sheet
    for row in ws.iter_rows(min_row=2, min_col=2, max_row=400, max_col=4):
#         print ("PRINTING CELL")
#         for cell in row:
#             print (cell.value, end = " ")
#         print ("ROW VALUE", row)
#         if isinstance(row[1].value, float) or isinstance(row[1].value, int):
#             print ("IF STATEMENT CHECK" + row[0].value[0])
#             try:
#                 if row[0].value[0] == "F":
#                     print ("Appending {} to F18".format(row[1].value))
#                     F18_Times.append(row[1].value)
#                     Individual_F18_Times.append(row[1].value)
#                 if row[0].value[0] == "E":
#                     print ("Appending {} to E2".format(row[1].value))
#                     E2_Times.append(row[1].value)
#                     Individual_E2_Times.append(row[1].value)
#             except:
#                 print ("skipping ", row[0].value)
        if row[2].value and isinstance(row[2].value, str) and "Expected" not in row[2].value and "ACtoAC" not in row[2].value:
            ac_to_person_violations += 1
            if isinstance(row[1].value, str):
                if "D" in row[1].value:
                    Yellow_Halo_Violations += 1
                if "CnC" in row[1].value:
                    Blue_Halo_Violations += 1
                if "B" in row[1].value:
                    Brown_Halo_Violations += 1
                if "W" in row[1].value:
                    White_Halo_Violations += 1
                if "G" in row[1].value:
                    Green_Halo_Violations += 1
                if "R" in row[1].value:
                    Red_Halo_Violations += 1
                if "P" in row[1].value:
                    Purple_Halo_Violations += 1
        if row[2].value and isinstance(row[2].value, str) and "ACtoAC" in row[2].value:
            ac_to_ac_violations += 1
            if row[0].value[0] == "F":
                F18_halo_violations += 1
            if row[0].value[0] == "E":
                E2_halo_violations += 1
                
    for row in ws.iter_rows(min_row=2, min_col=1, max_row=400, max_col=4):
        if row[0].value == 3:
            try:
                if row[1].value[0] == "F":
                    print ("Appending {} to F18".format(row[2].value))
                    F18_Times.append(row[2].value)
                    Individual_F18_Times.append(row[2].value)
                if row[1].value[0] == "E":
                    print ("Appending {} to E2".format(row[2].value))
                    E2_Times.append(row[2].value)
                    Individual_E2_Times.append(row[2].value)
            except:
                print ("skipping ", row[0].value)
                
    print ("TIMES", F18_Times, E2_Times)
    print ("AVERAGES", F18_Averages, E2_Averages)
    
    F18_Averages.append((current_sheet, Average(F18_Times)))
    E2_Averages.append((current_sheet, Average(E2_Times)))
    All_Averages.append((current_sheet, (Average(F18_Times) + Average(E2_Times))/2))
    F18_StdDevs.append((current_sheet, statistics.stdev(lstConvert(F18_Times))))
    try:
        E2_StdDevs.append((current_sheet, statistics.stdev(lstConvert(E2_Times))))
    except:
        E2_StdDevs.append((current_sheet, E2_Times[0]))
    AC_to_Person_unexpected_violations.append((current_sheet, ac_to_person_violations))
    AC_to_AC_unexpected_violations.append((current_sheet, ac_to_ac_violations))
    F18_Halo_Violations.append((current_sheet, F18_halo_violations))
    E2_Halo_Violations.append((current_sheet, E2_halo_violations))
    All_Yellow_Halo_Violations.append((current_sheet, Yellow_Halo_Violations))
    All_Blue_Halo_Violations.append((current_sheet, Blue_Halo_Violations))
    All_Brown_Halo_Violations.append((current_sheet, Brown_Halo_Violations))
    All_White_Halo_Violations.append((current_sheet, White_Halo_Violations))
    All_Green_Halo_Violations.append((current_sheet, Green_Halo_Violations))
    All_Red_Halo_Violations.append((current_sheet, Red_Halo_Violations))
    All_Purple_Halo_Violations.append((current_sheet, Purple_Halo_Violations))

print ("Finished Processing")
for tup in F18_Averages:
    print ("Sheet {}, Average {}".format(*tup))
print ("------")
for tup in E2_Averages:
    print ("Sheet {}, Average {}".format(*tup))
print ("------")
for tup in All_Averages:
    print ("Sheet {}, Average {}".format(*tup))
print ("------")
for tup in F18_StdDevs:
    print ("Sheet {}, Standard Deviation {}".format(*tup))
print ("------")
for tup in E2_StdDevs:
    print ("Sheet {}, Standard Deviation {}".format(*tup))
print ("------")
for tup in AC_to_Person_unexpected_violations:
    print ("Sheet {}, Number of Violations {}".format(*tup))
print ("------")
for tup in AC_to_AC_unexpected_violations:
    print ("Sheet {}, Number of Violations {}".format(*tup))
print ("------")
for tup in F18_Halo_Violations:
    print ("Sheet {}, Number of Violations {}".format(*tup))
print ("------")
for tup in E2_Halo_Violations:
    print ("Sheet {}, Number of Violations {}".format(*tup))
# Out:
# currently on  <Worksheet "Run 10.csv">
# Appending 802.74 to F18
# Appending 763.27 to F18
# Appending 479.31 to F18
# Appending 591.96 to F18
# Appending 392.56 to F18
# Appending 574.84 to F18
# Appending 548.1 to F18
# Appending 445.97 to F18
# Appending 363.27 to F18
# Appending 301.08 to E2
# TIMES [802.74, 763.27, 479.31, 591.96, 392.56, 574.84, 548.1, 445.97, 363.27] [301.08]
# AVERAGES [] []
# AVERAGING [802.74, 763.27, 479.31, 591.96, 392.56, 574.84, 548.1, 445.97, 363.27]
# RETURNING 551.3355555555556
# AVERAGING [301.08]
# RETURNING 301.08
# AVERAGING [802.74, 763.27, 479.31, 591.96, 392.56, 574.84, 548.1, 445.97, 363.27]
# RETURNING 551.3355555555556
# AVERAGING [301.08]
# RETURNING 301.08
# currently on  <Worksheet "Run 11.csv">
# Appending 761.65 to F18
# Appending 728.78 to F18
# Appending 566.17 to F18
# Appending 580.8 to F18
# Appending 357.66 to F18
# Appending 605.19 to F18
# Appending 512.86 to F18
# Appending 453.82 to F18
# Appending 414.94 to F18
# Appending 323.79 to E2
# TIMES [761.65, 728.78, 566.17, 580.8, 357.66, 605.19, 512.86, 453.82, 414.94] [323.79]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556)] [(<Worksheet "Run 10.csv">, 301.08)]
# AVERAGING [761.65, 728.78, 566.17, 580.8, 357.66, 605.19, 512.86, 453.82, 414.94]
# RETURNING 553.541111111111
# AVERAGING [323.79]
# RETURNING 323.79
# AVERAGING [761.65, 728.78, 566.17, 580.8, 357.66, 605.19, 512.86, 453.82, 414.94]
# RETURNING 553.541111111111
# AVERAGING [323.79]
# RETURNING 323.79
# currently on  <Worksheet "Run 13.csv">
# Appending 599.36 to F18
# Appending 563.5 to F18
# Appending 599.36 to F18
# Appending 743.8 to F18
# Appending 418.9 to F18
# Appending 631.65 to F18
# Appending 371.25 to F18
# Appending 474.7 to F18
# Appending 417.67 to F18
# Appending 329.29 to E2
# TIMES [599.36, 563.5, 599.36, 743.8, 418.9, 631.65, 371.25, 474.7, 417.67] [329.29]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79)]
# AVERAGING [599.36, 563.5, 599.36, 743.8, 418.9, 631.65, 371.25, 474.7, 417.67]
# RETURNING 535.5766666666667
# AVERAGING [329.29]
# RETURNING 329.29
# AVERAGING [599.36, 563.5, 599.36, 743.8, 418.9, 631.65, 371.25, 474.7, 417.67]
# RETURNING 535.5766666666667
# AVERAGING [329.29]
# RETURNING 329.29
# currently on  <Worksheet "Run 12.csv">
# Appending 711.41 to F18
# Appending 864.69 to F18
# Appending 539.67 to F18
# Appending 669.98 to F18
# Appending 536.1 to F18
# Appending 572.06 to F18
# Appending 386.78 to F18
# Appending 432.77 to F18
# Appending 397.47 to F18
# Appending 317.14 to E2
# TIMES [711.41, 864.69, 539.67, 669.98, 536.1, 572.06, 386.78, 432.77, 397.47] [317.14]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29)]
# AVERAGING [711.41, 864.69, 539.67, 669.98, 536.1, 572.06, 386.78, 432.77, 397.47]
# RETURNING 567.8811111111111
# AVERAGING [317.14]
# RETURNING 317.14
# AVERAGING [711.41, 864.69, 539.67, 669.98, 536.1, 572.06, 386.78, 432.77, 397.47]
# RETURNING 567.8811111111111
# AVERAGING [317.14]
# RETURNING 317.14
# currently on  <Worksheet "Run 16.csv">
# Appending 578.84 to F18
# Appending 541.24 to F18
# Appending 577.44 to F18
# Appending 703.88 to F18
# Appending 395.89 to F18
# Appending 482.46 to F18
# Appending 364.62 to F18
# Appending 426.42 to F18
# Appending 354.52 to F18
# Appending 270.34 to E2
# TIMES [578.84, 541.24, 577.44, 703.88, 395.89, 482.46, 364.62, 426.42, 354.52] [270.34]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14)]
# AVERAGING [578.84, 541.24, 577.44, 703.88, 395.89, 482.46, 364.62, 426.42, 354.52]
# RETURNING 491.70111111111106
# AVERAGING [270.34]
# RETURNING 270.34
# AVERAGING [578.84, 541.24, 577.44, 703.88, 395.89, 482.46, 364.62, 426.42, 354.52]
# RETURNING 491.70111111111106
# AVERAGING [270.34]
# RETURNING 270.34
# currently on  <Worksheet "Run 17.csv">
# Appending 805.37 to F18
# Appending 625.89 to F18
# Appending 541.49 to F18
# Appending 661.51 to F18
# Appending 442.9 to F18
# Appending 617.26 to F18
# Appending 408.76 to F18
# Appending 481.72 to F18
# Appending 410.63 to F18
# Appending 339.55 to E2
# TIMES [805.37, 625.89, 541.49, 661.51, 442.9, 617.26, 408.76, 481.72, 410.63] [339.55]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34)]
# AVERAGING [805.37, 625.89, 541.49, 661.51, 442.9, 617.26, 408.76, 481.72, 410.63]
# RETURNING 555.058888888889
# AVERAGING [339.55]
# RETURNING 339.55
# AVERAGING [805.37, 625.89, 541.49, 661.51, 442.9, 617.26, 408.76, 481.72, 410.63]
# RETURNING 555.058888888889
# AVERAGING [339.55]
# RETURNING 339.55
# currently on  <Worksheet "Run 15.csv">
# Appending 700.99 to F18
# Appending 732.84 to F18
# Appending 605.66 to F18
# Appending 565.58 to F18
# Appending 386.39 to F18
# Appending 530.66 to F18
# Appending 526.32 to F18
# Appending 463.28 to F18
# Appending 405.58 to F18
# Appending 304.91 to E2
# TIMES [700.99, 732.84, 605.66, 565.58, 386.39, 530.66, 526.32, 463.28, 405.58] [304.91]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55)]
# AVERAGING [700.99, 732.84, 605.66, 565.58, 386.39, 530.66, 526.32, 463.28, 405.58]
# RETURNING 546.3666666666666
# AVERAGING [304.91]
# RETURNING 304.91
# AVERAGING [700.99, 732.84, 605.66, 565.58, 386.39, 530.66, 526.32, 463.28, 405.58]
# RETURNING 546.3666666666666
# AVERAGING [304.91]
# RETURNING 304.91
# currently on  <Worksheet "Run 29.csv">
# Appending 669.3 to F18
# Appending 551.14 to F18
# Appending 506.39 to F18
# Appending 793.38 to F18
# Appending 407.16 to F18
# Appending 647.79 to F18
# Appending 371.89 to F18
# Appending 542.58 to F18
# Appending 414.77 to F18
# Appending 319.22 to E2
# TIMES [669.3, 551.14, 506.39, 793.38, 407.16, 647.79, 371.89, 542.58, 414.77] [319.22]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91)]
# AVERAGING [669.3, 551.14, 506.39, 793.38, 407.16, 647.79, 371.89, 542.58, 414.77]
# RETURNING 544.9333333333333
# AVERAGING [319.22]
# RETURNING 319.22
# AVERAGING [669.3, 551.14, 506.39, 793.38, 407.16, 647.79, 371.89, 542.58, 414.77]
# RETURNING 544.9333333333333
# AVERAGING [319.22]
# RETURNING 319.22
# currently on  <Worksheet "Run 28.csv">
# Appending 741.09 to F18
# Appending 614.93 to F18
# Appending 636.84 to F18
# Appending 653.85 to F18
# Appending 448.18 to F18
# Appending 552.65 to F18
# Appending 411.75 to F18
# Appending 519.56 to F18
# Appending 376.24 to F18
# Appending 324.25 to E2
# TIMES [741.09, 614.93, 636.84, 653.85, 448.18, 552.65, 411.75, 519.56, 376.24] [324.25]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22)]
# AVERAGING [741.09, 614.93, 636.84, 653.85, 448.18, 552.65, 411.75, 519.56, 376.24]
# RETURNING 550.5655555555555
# AVERAGING [324.25]
# RETURNING 324.25
# AVERAGING [741.09, 614.93, 636.84, 653.85, 448.18, 552.65, 411.75, 519.56, 376.24]
# RETURNING 550.5655555555555
# AVERAGING [324.25]
# RETURNING 324.25
# currently on  <Worksheet "Run 14.csv">
# Appending 642.66 to F18
# Appending 604.75 to F18
# Appending 543.35 to F18
# Appending 793.14 to F18
# Appending 461.91 to F18
# Appending 643.38 to F18
# Appending 425.84 to F18
# Appending 465.7 to F18
# Appending 427.18 to F18
# Appending 286.49 to E2
# TIMES [642.66, 604.75, 543.35, 793.14, 461.91, 643.38, 425.84, 465.7, 427.18] [286.49]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25)]
# AVERAGING [642.66, 604.75, 543.35, 793.14, 461.91, 643.38, 425.84, 465.7, 427.18]
# RETURNING 556.4344444444445
# AVERAGING [286.49]
# RETURNING 286.49
# AVERAGING [642.66, 604.75, 543.35, 793.14, 461.91, 643.38, 425.84, 465.7, 427.18]
# RETURNING 556.4344444444445
# AVERAGING [286.49]
# RETURNING 286.49
# currently on  <Worksheet "Run 9.csv">
# Appending 572.69 to F18
# Appending 785.25 to F18
# Appending 606.2 to F18
# Appending 748.64 to F18
# Appending 372.68 to F18
# Appending 551.52 to F18
# Appending 525.12 to F18
# Appending 462.26 to F18
# Appending 423.61 to F18
# Appending 334.13 to E2
# TIMES [572.69, 785.25, 606.2, 748.64, 372.68, 551.52, 525.12, 462.26, 423.61] [334.13]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49)]
# AVERAGING [572.69, 785.25, 606.2, 748.64, 372.68, 551.52, 525.12, 462.26, 423.61]
# RETURNING 560.8855555555556
# AVERAGING [334.13]
# RETURNING 334.13
# AVERAGING [572.69, 785.25, 606.2, 748.64, 372.68, 551.52, 525.12, 462.26, 423.61]
# RETURNING 560.8855555555556
# AVERAGING [334.13]
# RETURNING 334.13
# currently on  <Worksheet "Run 8.csv">
# Appending 647.55 to F18
# Appending 682.44 to F18
# Appending 553.11 to F18
# Appending 831.02 to F18
# Appending 505.13 to F18
# Appending 607.97 to F18
# Appending 421 to F18
# Appending 470.41 to F18
# Appending 398.89 to F18
# Appending 317.29 to E2
# TIMES [647.55, 682.44, 553.11, 831.02, 505.13, 607.97, 421, 470.41, 398.89] [317.29]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13)]
# AVERAGING [647.55, 682.44, 553.11, 831.02, 505.13, 607.97, 421, 470.41, 398.89]
# RETURNING 568.6133333333333
# AVERAGING [317.29]
# RETURNING 317.29
# AVERAGING [647.55, 682.44, 553.11, 831.02, 505.13, 607.97, 421, 470.41, 398.89]
# RETURNING 568.6133333333333
# AVERAGING [317.29]
# RETURNING 317.29
# currently on  <Worksheet "Run 5.csv">
# Appending 761.81 to F18
# Appending 584.98 to F18
# Appending 623.71 to F18
# Appending 624.37 to F18
# Appending 452.46 to F18
# Appending 660.37 to F18
# Appending 413.84 to F18
# Appending 494.27 to F18
# Appending 457.72 to F18
# Appending 290.05 to E2
# TIMES [761.81, 584.98, 623.71, 624.37, 452.46, 660.37, 413.84, 494.27, 457.72] [290.05]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29)]
# AVERAGING [761.81, 584.98, 623.71, 624.37, 452.46, 660.37, 413.84, 494.27, 457.72]
# RETURNING 563.7255555555555
# AVERAGING [290.05]
# RETURNING 290.05
# AVERAGING [761.81, 584.98, 623.71, 624.37, 452.46, 660.37, 413.84, 494.27, 457.72]
# RETURNING 563.7255555555555
# AVERAGING [290.05]
# RETURNING 290.05
# currently on  <Worksheet "Run 4.csv">
# Appending 847.52 to F18
# Appending 739.78 to F18
# Appending 556.16 to F18
# Appending 595.6 to F18
# Appending 452.2 to F18
# Appending 675.07 to F18
# Appending 410.57 to F18
# Appending 518.88 to F18
# Appending 385.58 to F18
# Appending 312.44 to E2
# TIMES [847.52, 739.78, 556.16, 595.6, 452.2, 675.07, 410.57, 518.88, 385.58] [312.44]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05)]
# AVERAGING [847.52, 739.78, 556.16, 595.6, 452.2, 675.07, 410.57, 518.88, 385.58]
# RETURNING 575.7066666666666
# AVERAGING [312.44]
# RETURNING 312.44
# AVERAGING [847.52, 739.78, 556.16, 595.6, 452.2, 675.07, 410.57, 518.88, 385.58]
# RETURNING 575.7066666666666
# AVERAGING [312.44]
# RETURNING 312.44
# currently on  <Worksheet "Run 6.csv">
# Appending 854.35 to F18
# Appending 701.02 to F18
# Appending 516.88 to F18
# Appending 658.62 to F18
# Appending 397.77 to F18
# Appending 596.88 to F18
# Appending 518.1 to F18
# Appending 456.21 to F18
# Appending 366.74 to F18
# Appending 294.88 to E2
# TIMES [854.35, 701.02, 516.88, 658.62, 397.77, 596.88, 518.1, 456.21, 366.74] [294.88]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44)]
# AVERAGING [854.35, 701.02, 516.88, 658.62, 397.77, 596.88, 518.1, 456.21, 366.74]
# RETURNING 562.9522222222222
# AVERAGING [294.88]
# RETURNING 294.88
# AVERAGING [854.35, 701.02, 516.88, 658.62, 397.77, 596.88, 518.1, 456.21, 366.74]
# RETURNING 562.9522222222222
# AVERAGING [294.88]
# RETURNING 294.88
# currently on  <Worksheet "Run 7.csv">
# Appending 729.27 to F18
# Appending 573.89 to F18
# Appending 531.02 to F18
# Appending 606.88 to F18
# Appending 399.58 to F18
# Appending 589.6 to F18
# Appending 363 to F18
# Appending 406.47 to F18
# Appending 449.04 to F18
# Appending 318.09 to E2
# TIMES [729.27, 573.89, 531.02, 606.88, 399.58, 589.6, 363, 406.47, 449.04] [318.09]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88)]
# AVERAGING [729.27, 573.89, 531.02, 606.88, 399.58, 589.6, 363, 406.47, 449.04]
# RETURNING 516.5277777777778
# AVERAGING [318.09]
# RETURNING 318.09
# AVERAGING [729.27, 573.89, 531.02, 606.88, 399.58, 589.6, 363, 406.47, 449.04]
# RETURNING 516.5277777777778
# AVERAGING [318.09]
# RETURNING 318.09
# currently on  <Worksheet "Run 3.csv">
# Appending 765.57 to F18
# Appending 610.57 to F18
# Appending 532.96 to F18
# Appending 880.51 to F18
# Appending 473.25 to F18
# Appending 665.82 to F18
# Appending 437.02 to F18
# Appending 566.23 to F18
# Appending 429.52 to F18
# Appending 340.11 to E2
# TIMES [765.57, 610.57, 532.96, 880.51, 473.25, 665.82, 437.02, 566.23, 429.52] [340.11]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09)]
# AVERAGING [765.57, 610.57, 532.96, 880.51, 473.25, 665.82, 437.02, 566.23, 429.52]
# RETURNING 595.7166666666667
# AVERAGING [340.11]
# RETURNING 340.11
# AVERAGING [765.57, 610.57, 532.96, 880.51, 473.25, 665.82, 437.02, 566.23, 429.52]
# RETURNING 595.7166666666667
# AVERAGING [340.11]
# RETURNING 340.11
# currently on  <Worksheet "Run 2.csv">
# Appending 587.58 to F18
# Appending 546.27 to F18
# Appending 532.4 to F18
# Appending 729.89 to F18
# Appending 394.95 to F18
# Appending 593.67 to F18
# Appending 359.93 to F18
# Appending 451.75 to F18
# Appending 394.95 to F18
# Appending 309.82 to E2
# TIMES [587.58, 546.27, 532.4, 729.89, 394.95, 593.67, 359.93, 451.75, 394.95] [309.82]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11)]
# AVERAGING [587.58, 546.27, 532.4, 729.89, 394.95, 593.67, 359.93, 451.75, 394.95]
# RETURNING 510.1544444444444
# AVERAGING [309.82]
# RETURNING 309.82
# AVERAGING [587.58, 546.27, 532.4, 729.89, 394.95, 593.67, 359.93, 451.75, 394.95]
# RETURNING 510.1544444444444
# AVERAGING [309.82]
# RETURNING 309.82
# currently on  <Worksheet "Run 1.csv">
# Appending 775.73 to F18
# Appending 601.61 to F18
# Appending 553.61 to F18
# Appending 810.07 to F18
# Appending 342.82 to F18
# Appending 660.51 to F18
# Appending 484.76 to F18
# Appending 510.23 to F18
# Appending 417.41 to F18
# Appending 346.86 to E2
# TIMES [775.73, 601.61, 553.61, 810.07, 342.82, 660.51, 484.76, 510.23, 417.41] [346.86]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82)]
# AVERAGING [775.73, 601.61, 553.61, 810.07, 342.82, 660.51, 484.76, 510.23, 417.41]
# RETURNING 572.9722222222222
# AVERAGING [346.86]
# RETURNING 346.86
# AVERAGING [775.73, 601.61, 553.61, 810.07, 342.82, 660.51, 484.76, 510.23, 417.41]
# RETURNING 572.9722222222222
# AVERAGING [346.86]
# RETURNING 346.86
# currently on  <Worksheet "Run 19.csv">
# Appending 726.23 to F18
# Appending 565.8 to F18
# Appending 582.05 to F18
# Appending 887.43 to F18
# Appending 426.34 to F18
# Appending 620.8 to F18
# Appending 392.35 to F18
# Appending 476.93 to F18
# Appending 435.18 to F18
# Appending 314.86 to E2
# TIMES [726.23, 565.8, 582.05, 887.43, 426.34, 620.8, 392.35, 476.93, 435.18] [314.86]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86)]
# AVERAGING [726.23, 565.8, 582.05, 887.43, 426.34, 620.8, 392.35, 476.93, 435.18]
# RETURNING 568.1233333333334
# AVERAGING [314.86]
# RETURNING 314.86
# AVERAGING [726.23, 565.8, 582.05, 887.43, 426.34, 620.8, 392.35, 476.93, 435.18]
# RETURNING 568.1233333333334
# AVERAGING [314.86]
# RETURNING 314.86
# currently on  <Worksheet "Run 25.csv">
# Appending 637.67 to F18
# Appending 601.51 to F18
# Appending 526.7 to F18
# Appending 772.58 to F18
# Appending 464.86 to F18
# Appending 664.83 to F18
# Appending 354.45 to F18
# Appending 566.32 to F18
# Appending 383.95 to F18
# Appending 302.29 to E2
# TIMES [637.67, 601.51, 526.7, 772.58, 464.86, 664.83, 354.45, 566.32, 383.95] [302.29]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86)]
# AVERAGING [637.67, 601.51, 526.7, 772.58, 464.86, 664.83, 354.45, 566.32, 383.95]
# RETURNING 552.5411111111111
# AVERAGING [302.29]
# RETURNING 302.29
# AVERAGING [637.67, 601.51, 526.7, 772.58, 464.86, 664.83, 354.45, 566.32, 383.95]
# RETURNING 552.5411111111111
# AVERAGING [302.29]
# RETURNING 302.29
# currently on  <Worksheet "Run 24.csv">
# Appending 642.3 to F18
# Appending 676.09 to F18
# Appending 539.86 to F18
# Appending 821.97 to F18
# Appending 471.34 to F18
# Appending 682.93 to F18
# Appending 435.15 to F18
# Appending 573.58 to F18
# Appending 433.64 to F18
# Appending 314.46 to E2
# TIMES [642.3, 676.09, 539.86, 821.97, 471.34, 682.93, 435.15, 573.58, 433.64] [314.46]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29)]
# AVERAGING [642.3, 676.09, 539.86, 821.97, 471.34, 682.93, 435.15, 573.58, 433.64]
# RETURNING 586.3177777777778
# AVERAGING [314.46]
# RETURNING 314.46
# AVERAGING [642.3, 676.09, 539.86, 821.97, 471.34, 682.93, 435.15, 573.58, 433.64]
# RETURNING 586.3177777777778
# AVERAGING [314.46]
# RETURNING 314.46
# currently on  <Worksheet "Run 30.csv">
# Appending 847.91 to F18
# Appending 673.49 to F18
# Appending 534.41 to F18
# Appending 712.49 to F18
# Appending 419.24 to F18
# Appending 616.86 to F18
# Appending 503.2 to F18
# Appending 485.85 to F18
# Appending 403 to F18
# Appending 330.81 to E2
# TIMES [847.91, 673.49, 534.41, 712.49, 419.24, 616.86, 503.2, 485.85, 403] [330.81]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111), (<Worksheet "Run 24.csv">, 586.3177777777778)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29), (<Worksheet "Run 24.csv">, 314.46)]
# AVERAGING [847.91, 673.49, 534.41, 712.49, 419.24, 616.86, 503.2, 485.85, 403]
# RETURNING 577.3833333333334
# AVERAGING [330.81]
# RETURNING 330.81
# AVERAGING [847.91, 673.49, 534.41, 712.49, 419.24, 616.86, 503.2, 485.85, 403]
# RETURNING 577.3833333333334
# AVERAGING [330.81]
# RETURNING 330.81
# currently on  <Worksheet "Run 18.csv">
# Appending 755.04 to F18
# Appending 583.96 to F18
# Appending 579.22 to F18
# Appending 618.76 to F18
# Appending 448.33 to F18
# Appending 624.26 to F18
# Appending 412.86 to F18
# Appending 481.92 to F18
# Appending 441.68 to F18
# Appending 324.84 to E2
# TIMES [755.04, 583.96, 579.22, 618.76, 448.33, 624.26, 412.86, 481.92, 441.68] [324.84]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111), (<Worksheet "Run 24.csv">, 586.3177777777778), (<Worksheet "Run 30.csv">, 577.3833333333334)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29), (<Worksheet "Run 24.csv">, 314.46), (<Worksheet "Run 30.csv">, 330.81)]
# AVERAGING [755.04, 583.96, 579.22, 618.76, 448.33, 624.26, 412.86, 481.92, 441.68]
# RETURNING 549.5588888888889
# AVERAGING [324.84]
# RETURNING 324.84
# AVERAGING [755.04, 583.96, 579.22, 618.76, 448.33, 624.26, 412.86, 481.92, 441.68]
# RETURNING 549.5588888888889
# AVERAGING [324.84]
# RETURNING 324.84
# currently on  <Worksheet "Run 26.csv">
# Appending 842.08 to F18
# Appending 661.16 to F18
# Appending 589.23 to F18
# Appending 693.05 to F18
# Appending 495.81 to F18
# Appending 721.65 to F18
# Appending 380.75 to F18
# Appending 546.42 to F18
# Appending 410.64 to F18
# Appending 329.87 to E2
# TIMES [842.08, 661.16, 589.23, 693.05, 495.81, 721.65, 380.75, 546.42, 410.64] [329.87]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111), (<Worksheet "Run 24.csv">, 586.3177777777778), (<Worksheet "Run 30.csv">, 577.3833333333334), (<Worksheet "Run 18.csv">, 549.5588888888889)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29), (<Worksheet "Run 24.csv">, 314.46), (<Worksheet "Run 30.csv">, 330.81), (<Worksheet "Run 18.csv">, 324.84)]
# AVERAGING [842.08, 661.16, 589.23, 693.05, 495.81, 721.65, 380.75, 546.42, 410.64]
# RETURNING 593.4211111111113
# AVERAGING [329.87]
# RETURNING 329.87
# AVERAGING [842.08, 661.16, 589.23, 693.05, 495.81, 721.65, 380.75, 546.42, 410.64]
# RETURNING 593.4211111111113
# AVERAGING [329.87]
# RETURNING 329.87
# currently on  <Worksheet "Run 27.csv">
# Appending 596.34 to F18
# Appending 785.05 to F18
# Appending 543.03 to F18
# Appending 749.93 to F18
# Appending 397.36 to F18
# Appending 586.97 to F18
# Appending 547.53 to F18
# Appending 457.92 to F18
# Appending 410.55 to F18
# Appending 313.19 to E2
# TIMES [596.34, 785.05, 543.03, 749.93, 397.36, 586.97, 547.53, 457.92, 410.55] [313.19]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111), (<Worksheet "Run 24.csv">, 586.3177777777778), (<Worksheet "Run 30.csv">, 577.3833333333334), (<Worksheet "Run 18.csv">, 549.5588888888889), (<Worksheet "Run 26.csv">, 593.4211111111113)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29), (<Worksheet "Run 24.csv">, 314.46), (<Worksheet "Run 30.csv">, 330.81), (<Worksheet "Run 18.csv">, 324.84), (<Worksheet "Run 26.csv">, 329.87)]
# AVERAGING [596.34, 785.05, 543.03, 749.93, 397.36, 586.97, 547.53, 457.92, 410.55]
# RETURNING 563.8533333333334
# AVERAGING [313.19]
# RETURNING 313.19
# AVERAGING [596.34, 785.05, 543.03, 749.93, 397.36, 586.97, 547.53, 457.92, 410.55]
# RETURNING 563.8533333333334
# AVERAGING [313.19]
# RETURNING 313.19
# currently on  <Worksheet "Run 23.csv">
# Appending 672.04 to F18
# Appending 704.45 to F18
# Appending 644.33 to F18
# Appending 737.02 to F18
# Appending 496.33 to F18
# Appending 515.54 to F18
# Appending 423.01 to F18
# Appending 465.74 to F18
# Appending 389.9 to F18
# Appending 319.61 to E2
# TIMES [672.04, 704.45, 644.33, 737.02, 496.33, 515.54, 423.01, 465.74, 389.9] [319.61]
# AVERAGES [(<Worksheet "Run 10.csv">, 551.3355555555556), (<Worksheet "Run 11.csv">, 553.541111111111), (<Worksheet "Run 13.csv">, 535.5766666666667), (<Worksheet "Run 12.csv">, 567.8811111111111), (<Worksheet "Run 16.csv">, 491.70111111111106), (<Worksheet "Run 17.csv">, 555.058888888889), (<Worksheet "Run 15.csv">, 546.3666666666666), (<Worksheet "Run 29.csv">, 544.9333333333333), (<Worksheet "Run 28.csv">, 550.5655555555555), (<Worksheet "Run 14.csv">, 556.4344444444445), (<Worksheet "Run 9.csv">, 560.8855555555556), (<Worksheet "Run 8.csv">, 568.6133333333333), (<Worksheet "Run 5.csv">, 563.7255555555555), (<Worksheet "Run 4.csv">, 575.7066666666666), (<Worksheet "Run 6.csv">, 562.9522222222222), (<Worksheet "Run 7.csv">, 516.5277777777778), (<Worksheet "Run 3.csv">, 595.7166666666667), (<Worksheet "Run 2.csv">, 510.1544444444444), (<Worksheet "Run 1.csv">, 572.9722222222222), (<Worksheet "Run 19.csv">, 568.1233333333334), (<Worksheet "Run 25.csv">, 552.5411111111111), (<Worksheet "Run 24.csv">, 586.3177777777778), (<Worksheet "Run 30.csv">, 577.3833333333334), (<Worksheet "Run 18.csv">, 549.5588888888889), (<Worksheet "Run 26.csv">, 593.4211111111113), (<Worksheet "Run 27.csv">, 563.8533333333334)] [(<Worksheet "Run 10.csv">, 301.08), (<Worksheet "Run 11.csv">, 323.79), (<Worksheet "Run 13.csv">, 329.29), (<Worksheet "Run 12.csv">, 317.14), (<Worksheet "Run 16.csv">, 270.34), (<Worksheet "Run 17.csv">, 339.55), (<Worksheet "Run 15.csv">, 304.91), (<Worksheet "Run 29.csv">, 319.22), (<Worksheet "Run 28.csv">, 324.25), (<Worksheet "Run 14.csv">, 286.49), (<Worksheet "Run 9.csv">, 334.13), (<Worksheet "Run 8.csv">, 317.29), (<Worksheet "Run 5.csv">, 290.05), (<Worksheet "Run 4.csv">, 312.44), (<Worksheet "Run 6.csv">, 294.88), (<Worksheet "Run 7.csv">, 318.09), (<Worksheet "Run 3.csv">, 340.11), (<Worksheet "Run 2.csv">, 309.82), (<Worksheet "Run 1.csv">, 346.86), (<Worksheet "Run 19.csv">, 314.86), (<Worksheet "Run 25.csv">, 302.29), (<Worksheet "Run 24.csv">, 314.46), (<Worksheet "Run 30.csv">, 330.81), (<Worksheet "Run 18.csv">, 324.84), (<Worksheet "Run 26.csv">, 329.87), (<Worksheet "Run 27.csv">, 313.19)]
# AVERAGING [672.04, 704.45, 644.33, 737.02, 496.33, 515.54, 423.01, 465.74, 389.9]
# RETURNING 560.9288888888889
# AVERAGING [319.61]
# RETURNING 319.61
# AVERAGING [672.04, 704.45, 644.33, 737.02, 496.33, 515.54, 423.01, 465.74, 389.9]
# RETURNING 560.9288888888889
# AVERAGING [319.61]
# RETURNING 319.61
# currently on  <Worksheet "Run 22.csv">
# Appending 624.78 to F18
# Appending 657.65 to F18
# Appending 531.31 to F18
# Appending 801.69 to F18
# Appending 485.49 to F18
# Appending 623.99 to F18
# Appending 393.81 to F18
# Appending 394.53 to F18
# Appending 474.02 to F18
# Appending 322.9 to E2
# TIMES [624.78, 657.65, 531.31, 801.69, 485.49, 623.99, 393.81, 394.53, 474.02] [322.9]
# ...
# AVERAGING [760.35, 724.87, 536.02, 599.38, 393.88, 589.46, 524.75, 456.02, 398.51]
# RETURNING 553.6933333333333
# AVERAGING [314.37]
# RETURNING 314.37
# AVERAGING [760.35, 724.87, 536.02, 599.38, 393.88, 589.46, 524.75, 456.02, 398.51]
# RETURNING 553.6933333333333
# AVERAGING [314.37]
# RETURNING 314.37
# Finished Processing
# Sheet <Worksheet "Run 10.csv">, Average 551.3355555555556
# Sheet <Worksheet "Run 11.csv">, Average 553.541111111111
# Sheet <Worksheet "Run 13.csv">, Average 535.5766666666667
# Sheet <Worksheet "Run 12.csv">, Average 567.8811111111111
# Sheet <Worksheet "Run 16.csv">, Average 491.70111111111106
# Sheet <Worksheet "Run 17.csv">, Average 555.058888888889
# Sheet <Worksheet "Run 15.csv">, Average 546.3666666666666
# Sheet <Worksheet "Run 29.csv">, Average 544.9333333333333
# Sheet <Worksheet "Run 28.csv">, Average 550.5655555555555
# Sheet <Worksheet "Run 14.csv">, Average 556.4344444444445
# Sheet <Worksheet "Run 9.csv">, Average 560.8855555555556
# Sheet <Worksheet "Run 8.csv">, Average 568.6133333333333
# Sheet <Worksheet "Run 5.csv">, Average 563.7255555555555
# Sheet <Worksheet "Run 4.csv">, Average 575.7066666666666
# Sheet <Worksheet "Run 6.csv">, Average 562.9522222222222
# Sheet <Worksheet "Run 7.csv">, Average 516.5277777777778
# Sheet <Worksheet "Run 3.csv">, Average 595.7166666666667
# Sheet <Worksheet "Run 2.csv">, Average 510.1544444444444
# Sheet <Worksheet "Run 1.csv">, Average 572.9722222222222
# Sheet <Worksheet "Run 19.csv">, Average 568.1233333333334
# Sheet <Worksheet "Run 25.csv">, Average 552.5411111111111
# Sheet <Worksheet "Run 24.csv">, Average 586.3177777777778
# Sheet <Worksheet "Run 30.csv">, Average 577.3833333333334
# Sheet <Worksheet "Run 18.csv">, Average 549.5588888888889
# Sheet <Worksheet "Run 26.csv">, Average 593.4211111111113
# Sheet <Worksheet "Run 27.csv">, Average 563.8533333333334
# Sheet <Worksheet "Run 23.csv">, Average 560.9288888888889
# Sheet <Worksheet "Run 22.csv">, Average 554.1411111111112
# Sheet <Worksheet "Run 20.csv">, Average 550.9911111111111
# Sheet <Worksheet "Run 21.csv">, Average 553.6933333333333
# ------
# Sheet <Worksheet "Run 10.csv">, Average 301.08
# Sheet <Worksheet "Run 11.csv">, Average 323.79
# Sheet <Worksheet "Run 13.csv">, Average 329.29
# Sheet <Worksheet "Run 12.csv">, Average 317.14
# Sheet <Worksheet "Run 16.csv">, Average 270.34
# Sheet <Worksheet "Run 17.csv">, Average 339.55
# Sheet <Worksheet "Run 15.csv">, Average 304.91
# Sheet <Worksheet "Run 29.csv">, Average 319.22
# Sheet <Worksheet "Run 28.csv">, Average 324.25
# Sheet <Worksheet "Run 14.csv">, Average 286.49
# Sheet <Worksheet "Run 9.csv">, Average 334.13
# Sheet <Worksheet "Run 8.csv">, Average 317.29
# Sheet <Worksheet "Run 5.csv">, Average 290.05
# Sheet <Worksheet "Run 4.csv">, Average 312.44
# Sheet <Worksheet "Run 6.csv">, Average 294.88
# Sheet <Worksheet "Run 7.csv">, Average 318.09
# Sheet <Worksheet "Run 3.csv">, Average 340.11
# Sheet <Worksheet "Run 2.csv">, Average 309.82
# Sheet <Worksheet "Run 1.csv">, Average 346.86
# Sheet <Worksheet "Run 19.csv">, Average 314.86
# Sheet <Worksheet "Run 25.csv">, Average 302.29
# Sheet <Worksheet "Run 24.csv">, Average 314.46
# Sheet <Worksheet "Run 30.csv">, Average 330.81
# Sheet <Worksheet "Run 18.csv">, Average 324.84
# Sheet <Worksheet "Run 26.csv">, Average 329.87
# Sheet <Worksheet "Run 27.csv">, Average 313.19
# Sheet <Worksheet "Run 23.csv">, Average 319.61
# Sheet <Worksheet "Run 22.csv">, Average 322.9
# Sheet <Worksheet "Run 20.csv">, Average 321.09
# Sheet <Worksheet "Run 21.csv">, Average 314.37
# ------
# Sheet <Worksheet "Run 10.csv">, Average 426.2077777777778
# Sheet <Worksheet "Run 11.csv">, Average 438.66555555555556
# Sheet <Worksheet "Run 13.csv">, Average 432.4333333333334
# Sheet <Worksheet "Run 12.csv">, Average 442.5105555555555
# Sheet <Worksheet "Run 16.csv">, Average 381.0205555555555
# Sheet <Worksheet "Run 17.csv">, Average 447.30444444444447
# Sheet <Worksheet "Run 15.csv">, Average 425.6383333333333
# Sheet <Worksheet "Run 29.csv">, Average 432.07666666666665
# Sheet <Worksheet "Run 28.csv">, Average 437.40777777777777
# Sheet <Worksheet "Run 14.csv">, Average 421.46222222222224
# Sheet <Worksheet "Run 9.csv">, Average 447.5077777777778
# Sheet <Worksheet "Run 8.csv">, Average 442.9516666666667
# Sheet <Worksheet "Run 5.csv">, Average 426.8877777777777
# Sheet <Worksheet "Run 4.csv">, Average 444.07333333333327
# Sheet <Worksheet "Run 6.csv">, Average 428.9161111111111
# Sheet <Worksheet "Run 7.csv">, Average 417.3088888888889
# Sheet <Worksheet "Run 3.csv">, Average 467.91333333333336
# Sheet <Worksheet "Run 2.csv">, Average 409.98722222222216
# Sheet <Worksheet "Run 1.csv">, Average 459.9161111111111
# Sheet <Worksheet "Run 19.csv">, Average 441.49166666666673
# Sheet <Worksheet "Run 25.csv">, Average 427.41555555555556
# Sheet <Worksheet "Run 24.csv">, Average 450.3888888888889
# Sheet <Worksheet "Run 30.csv">, Average 454.0966666666667
# Sheet <Worksheet "Run 18.csv">, Average 437.19944444444445
# Sheet <Worksheet "Run 26.csv">, Average 461.64555555555563
# Sheet <Worksheet "Run 27.csv">, Average 438.52166666666665
# Sheet <Worksheet "Run 23.csv">, Average 440.26944444444445
# Sheet <Worksheet "Run 22.csv">, Average 438.5205555555556
# Sheet <Worksheet "Run 20.csv">, Average 436.04055555555556
# Sheet <Worksheet "Run 21.csv">, Average 434.03166666666664
# ------
# Sheet <Worksheet "Run 10.csv">, Standard Deviation 152.97123415131938
# Sheet <Worksheet "Run 11.csv">, Standard Deviation 135.44696927621197
# Sheet <Worksheet "Run 13.csv">, Standard Deviation 122.33561940416207
# Sheet <Worksheet "Run 12.csv">, Standard Deviation 158.5229408038821
# Sheet <Worksheet "Run 16.csv">, Standard Deviation 117.74622185493304
# Sheet <Worksheet "Run 17.csv">, Standard Deviation 133.8277383845035
# Sheet <Worksheet "Run 15.csv">, Standard Deviation 120.1722267206529
# Sheet <Worksheet "Run 29.csv">, Standard Deviation 139.27039222318575
# Sheet <Worksheet "Run 28.csv">, Standard Deviation 122.30134454607513
# Sheet <Worksheet "Run 14.csv">, Standard Deviation 124.7290673932014
# Sheet <Worksheet "Run 9.csv">, Standard Deviation 138.35808488403478
# Sheet <Worksheet "Run 8.csv">, Standard Deviation 138.79112048326434
# Sheet <Worksheet "Run 5.csv">, Standard Deviation 115.7649477509396
# Sheet <Worksheet "Run 4.csv">, Standard Deviation 155.46497620042916
# Sheet <Worksheet "Run 6.csv">, Standard Deviation 156.36154824458745
# Sheet <Worksheet "Run 7.csv">, Standard Deviation 120.50811785703253
# Sheet <Worksheet "Run 3.csv">, Standard Deviation 153.17653524610094
# Sheet <Worksheet "Run 2.csv">, Standard Deviation 120.19518918316896
# Sheet <Worksheet "Run 1.csv">, Standard Deviation 156.15360472766696
# Sheet <Worksheet "Run 19.csv">, Standard Deviation 160.8250519975044
# Sheet <Worksheet "Run 25.csv">, Standard Deviation 135.498817379013
# Sheet <Worksheet "Run 24.csv">, Standard Deviation 131.22576859917584
# Sheet <Worksheet "Run 30.csv">, Standard Deviation 147.21602901858208
# Sheet <Worksheet "Run 18.csv">, Standard Deviation 111.6923804971096
# Sheet <Worksheet "Run 26.csv">, Standard Deviation 151.31957015241323
# Sheet <Worksheet "Run 27.csv">, Standard Deviation 136.14612122642347
# Sheet <Worksheet "Run 23.csv">, Standard Deviation 129.6506874687177
# Sheet <Worksheet "Run 22.csv">, Standard Deviation 134.48915452969104
# Sheet <Worksheet "Run 20.csv">, Standard Deviation 129.5349631802592
# Sheet <Worksheet "Run 21.csv">, Standard Deviation 130.23405219066174
# ------
# Sheet <Worksheet "Run 10.csv">, Standard Deviation 301.08
# Sheet <Worksheet "Run 11.csv">, Standard Deviation 323.79
# Sheet <Worksheet "Run 13.csv">, Standard Deviation 329.29
# Sheet <Worksheet "Run 12.csv">, Standard Deviation 317.14
# Sheet <Worksheet "Run 16.csv">, Standard Deviation 270.34
# Sheet <Worksheet "Run 17.csv">, Standard Deviation 339.55
# Sheet <Worksheet "Run 15.csv">, Standard Deviation 304.91
# Sheet <Worksheet "Run 29.csv">, Standard Deviation 319.22
# Sheet <Worksheet "Run 28.csv">, Standard Deviation 324.25
# Sheet <Worksheet "Run 14.csv">, Standard Deviation 286.49
# Sheet <Worksheet "Run 9.csv">, Standard Deviation 334.13
# Sheet <Worksheet "Run 8.csv">, Standard Deviation 317.29
# Sheet <Worksheet "Run 5.csv">, Standard Deviation 290.05
# Sheet <Worksheet "Run 4.csv">, Standard Deviation 312.44
# Sheet <Worksheet "Run 6.csv">, Standard Deviation 294.88
# Sheet <Worksheet "Run 7.csv">, Standard Deviation 318.09
# Sheet <Worksheet "Run 3.csv">, Standard Deviation 340.11
# Sheet <Worksheet "Run 2.csv">, Standard Deviation 309.82
# Sheet <Worksheet "Run 1.csv">, Standard Deviation 346.86
# Sheet <Worksheet "Run 19.csv">, Standard Deviation 314.86
# Sheet <Worksheet "Run 25.csv">, Standard Deviation 302.29
# Sheet <Worksheet "Run 24.csv">, Standard Deviation 314.46
# Sheet <Worksheet "Run 30.csv">, Standard Deviation 330.81
# Sheet <Worksheet "Run 18.csv">, Standard Deviation 324.84
# Sheet <Worksheet "Run 26.csv">, Standard Deviation 329.87
# Sheet <Worksheet "Run 27.csv">, Standard Deviation 313.19
# Sheet <Worksheet "Run 23.csv">, Standard Deviation 319.61
# Sheet <Worksheet "Run 22.csv">, Standard Deviation 322.9
# Sheet <Worksheet "Run 20.csv">, Standard Deviation 321.09
# Sheet <Worksheet "Run 21.csv">, Standard Deviation 314.37
# ------
# Sheet <Worksheet "Run 10.csv">, Number of Violations 19
# Sheet <Worksheet "Run 11.csv">, Number of Violations 22
# Sheet <Worksheet "Run 13.csv">, Number of Violations 24
# Sheet <Worksheet "Run 12.csv">, Number of Violations 28
# Sheet <Worksheet "Run 16.csv">, Number of Violations 16
# Sheet <Worksheet "Run 17.csv">, Number of Violations 31
# Sheet <Worksheet "Run 15.csv">, Number of Violations 17
# Sheet <Worksheet "Run 29.csv">, Number of Violations 23
# Sheet <Worksheet "Run 28.csv">, Number of Violations 24
# Sheet <Worksheet "Run 14.csv">, Number of Violations 20
# Sheet <Worksheet "Run 9.csv">, Number of Violations 11
# Sheet <Worksheet "Run 8.csv">, Number of Violations 26
# Sheet <Worksheet "Run 5.csv">, Number of Violations 23
# Sheet <Worksheet "Run 4.csv">, Number of Violations 20
# Sheet <Worksheet "Run 6.csv">, Number of Violations 30
# Sheet <Worksheet "Run 7.csv">, Number of Violations 18
# Sheet <Worksheet "Run 3.csv">, Number of Violations 28
# Sheet <Worksheet "Run 2.csv">, Number of Violations 18
# Sheet <Worksheet "Run 1.csv">, Number of Violations 19
# Sheet <Worksheet "Run 19.csv">, Number of Violations 17
# Sheet <Worksheet "Run 25.csv">, Number of Violations 18
# Sheet <Worksheet "Run 24.csv">, Number of Violations 19
# Sheet <Worksheet "Run 30.csv">, Number of Violations 22
# Sheet <Worksheet "Run 18.csv">, Number of Violations 19
# Sheet <Worksheet "Run 26.csv">, Number of Violations 15
# Sheet <Worksheet "Run 27.csv">, Number of Violations 19
# Sheet <Worksheet "Run 23.csv">, Number of Violations 15
# Sheet <Worksheet "Run 22.csv">, Number of Violations 12
# Sheet <Worksheet "Run 20.csv">, Number of Violations 23
# Sheet <Worksheet "Run 21.csv">, Number of Violations 19
# ------
# Sheet <Worksheet "Run 10.csv">, Number of Violations 1
# Sheet <Worksheet "Run 11.csv">, Number of Violations 1
# Sheet <Worksheet "Run 13.csv">, Number of Violations 1
# Sheet <Worksheet "Run 12.csv">, Number of Violations 1
# Sheet <Worksheet "Run 16.csv">, Number of Violations 1
# Sheet <Worksheet "Run 17.csv">, Number of Violations 1
# Sheet <Worksheet "Run 15.csv">, Number of Violations 1
# Sheet <Worksheet "Run 29.csv">, Number of Violations 1
# Sheet <Worksheet "Run 28.csv">, Number of Violations 1
# Sheet <Worksheet "Run 14.csv">, Number of Violations 1
# Sheet <Worksheet "Run 9.csv">, Number of Violations 1
# Sheet <Worksheet "Run 8.csv">, Number of Violations 1
# Sheet <Worksheet "Run 5.csv">, Number of Violations 1
# Sheet <Worksheet "Run 4.csv">, Number of Violations 1
# Sheet <Worksheet "Run 6.csv">, Number of Violations 1
# Sheet <Worksheet "Run 7.csv">, Number of Violations 3
# Sheet <Worksheet "Run 3.csv">, Number of Violations 1
# Sheet <Worksheet "Run 2.csv">, Number of Violations 1
# Sheet <Worksheet "Run 1.csv">, Number of Violations 1
# Sheet <Worksheet "Run 19.csv">, Number of Violations 1
# Sheet <Worksheet "Run 25.csv">, Number of Violations 1
# Sheet <Worksheet "Run 24.csv">, Number of Violations 1
# Sheet <Worksheet "Run 30.csv">, Number of Violations 1
# Sheet <Worksheet "Run 18.csv">, Number of Violations 1
# Sheet <Worksheet "Run 26.csv">, Number of Violations 1
# Sheet <Worksheet "Run 27.csv">, Number of Violations 1
# Sheet <Worksheet "Run 23.csv">, Number of Violations 1
# Sheet <Worksheet "Run 22.csv">, Number of Violations 1
# Sheet <Worksheet "Run 20.csv">, Number of Violations 1
# Sheet <Worksheet "Run 21.csv">, Number of Violations 1
# ------
# Sheet <Worksheet "Run 10.csv">, Number of Violations 0
# Sheet <Worksheet "Run 11.csv">, Number of Violations 0
# Sheet <Worksheet "Run 13.csv">, Number of Violations 0
# Sheet <Worksheet "Run 12.csv">, Number of Violations 0
# Sheet <Worksheet "Run 16.csv">, Number of Violations 0
# Sheet <Worksheet "Run 17.csv">, Number of Violations 0
# Sheet <Worksheet "Run 15.csv">, Number of Violations 0
# Sheet <Worksheet "Run 29.csv">, Number of Violations 0
# Sheet <Worksheet "Run 28.csv">, Number of Violations 0
# Sheet <Worksheet "Run 14.csv">, Number of Violations 0
# Sheet <Worksheet "Run 9.csv">, Number of Violations 0
# Sheet <Worksheet "Run 8.csv">, Number of Violations 0
# Sheet <Worksheet "Run 5.csv">, Number of Violations 0
# Sheet <Worksheet "Run 4.csv">, Number of Violations 0
# Sheet <Worksheet "Run 6.csv">, Number of Violations 0
# Sheet <Worksheet "Run 7.csv">, Number of Violations 2
# Sheet <Worksheet "Run 3.csv">, Number of Violations 0
# Sheet <Worksheet "Run 2.csv">, Number of Violations 0
# Sheet <Worksheet "Run 1.csv">, Number of Violations 0
# Sheet <Worksheet "Run 19.csv">, Number of Violations 0
# Sheet <Worksheet "Run 25.csv">, Number of Violations 0
# Sheet <Worksheet "Run 24.csv">, Number of Violations 0
# Sheet <Worksheet "Run 30.csv">, Number of Violations 0
# Sheet <Worksheet "Run 18.csv">, Number of Violations 0
# Sheet <Worksheet "Run 26.csv">, Number of Violations 0
# Sheet <Worksheet "Run 27.csv">, Number of Violations 0
# Sheet <Worksheet "Run 23.csv">, Number of Violations 0
# Sheet <Worksheet "Run 22.csv">, Number of Violations 0
# Sheet <Worksheet "Run 20.csv">, Number of Violations 0
# Sheet <Worksheet "Run 21.csv">, Number of Violations 0
# ------
# Sheet <Worksheet "Run 10.csv">, Number of Violations 1
# Sheet <Worksheet "Run 11.csv">, Number of Violations 1
# Sheet <Worksheet "Run 13.csv">, Number of Violations 1
# Sheet <Worksheet "Run 12.csv">, Number of Violations 1
# Sheet <Worksheet "Run 16.csv">, Number of Violations 1
# Sheet <Worksheet "Run 17.csv">, Number of Violations 1
# Sheet <Worksheet "Run 15.csv">, Number of Violations 1
# Sheet <Worksheet "Run 29.csv">, Number of Violations 1
# Sheet <Worksheet "Run 28.csv">, Number of Violations 1
# Sheet <Worksheet "Run 14.csv">, Number of Violations 1
# Sheet <Worksheet "Run 9.csv">, Number of Violations 1
# Sheet <Worksheet "Run 8.csv">, Number of Violations 1
# Sheet <Worksheet "Run 5.csv">, Number of Violations 1
# Sheet <Worksheet "Run 4.csv">, Number of Violations 1
# Sheet <Worksheet "Run 6.csv">, Number of Violations 1
# Sheet <Worksheet "Run 7.csv">, Number of Violations 1
# Sheet <Worksheet "Run 3.csv">, Number of Violations 1
# Sheet <Worksheet "Run 2.csv">, Number of Violations 1
# Sheet <Worksheet "Run 1.csv">, Number of Violations 1
# Sheet <Worksheet "Run 19.csv">, Number of Violations 1
# Sheet <Worksheet "Run 25.csv">, Number of Violations 1
# Sheet <Worksheet "Run 24.csv">, Number of Violations 1
# Sheet <Worksheet "Run 30.csv">, Number of Violations 1
# Sheet <Worksheet "Run 18.csv">, Number of Violations 1
# Sheet <Worksheet "Run 26.csv">, Number of Violations 1
# Sheet <Worksheet "Run 27.csv">, Number of Violations 1
# Sheet <Worksheet "Run 23.csv">, Number of Violations 1
# Sheet <Worksheet "Run 22.csv">, Number of Violations 1
# Sheet <Worksheet "Run 20.csv">, Number of Violations 1
# Sheet <Worksheet "Run 21.csv">, Number of Violations 1

# %%
aggregate = sheets[-1]
for index in range(len(All_Averages)):
    average_current_cell = aggregate.cell(row=index+2, column=3)
    F18_current_cell = aggregate.cell(row=index+2, column=4)
    E2_current_cell = aggregate.cell(row=index+2, column=5)
    F18_stdDev_cell = aggregate.cell(row=index+2, column=6)
    E2_stdDev_cell = aggregate.cell(row=index+2, column=7)
    total_ac_to_ac_violations_cell = aggregate.cell(row=index+2, column=8)
    F18_unexpected_violations = aggregate.cell(row=index+2, column=9)
    E2_unexpected_violations = aggregate.cell(row=index+2, column=10)
    total_ac_to_person_violations_cell = aggregate.cell(row=index+2, column=11)
    All_Brown_Halo_Violations_cell = aggregate.cell(row=index+2, column=12)
    All_Blue_Halo_Violations_cell = aggregate.cell(row=index+2, column=13)
    All_White_Halo_Violations_cell = aggregate.cell(row=index+2, column=14)
    All_Green_Halo_Violations_cell = aggregate.cell(row=index+2, column=15)
    All_Red_Halo_Violations_cell = aggregate.cell(row=index+2, column=16)
    All_Purple_Halo_Violations_cell = aggregate.cell(row=index+2, column=17)
    All_Yellow_Halo_Violations_cell = aggregate.cell(row=index+2, column=18)
    try:
        average_current_cell.value = All_Averages[index][1]
    except:
        print (index, All_Averages, len(All_Averages), len(All_Blue_Halo_Violations))
        print ("Could not add index " , index)
    F18_current_cell.value = F18_Averages[index][1]
    E2_current_cell.value = E2_Averages[index][1]
    F18_stdDev_cell.value = F18_StdDevs[index][1]
    E2_stdDev_cell.value = E2_StdDevs[index][1]
    total_ac_to_ac_violations_cell.value = AC_to_AC_unexpected_violations[index][1]
    F18_unexpected_violations.value = F18_Halo_Violations[index][1]
    E2_unexpected_violations.value = E2_Halo_Violations[index][1]
    total_ac_to_person_violations_cell.value = AC_to_Person_unexpected_violations[index][1]
    All_Brown_Halo_Violations_cell.value = All_Brown_Halo_Violations[index][1]
    All_Blue_Halo_Violations_cell.value = All_Blue_Halo_Violations[index][1]
    All_White_Halo_Violations_cell.value = All_White_Halo_Violations[index][1]
    All_Green_Halo_Violations_cell.value = All_Green_Halo_Violations[index][1]
    All_Red_Halo_Violations_cell.value = All_Red_Halo_Violations[index][1]
    All_Purple_Halo_Violations_cell.value = All_Purple_Halo_Violations[index][1]
    All_Yellow_Halo_Violations_cell.value = All_Yellow_Halo_Violations[index][1]
    
wb.save(input_workbook)
print ("Finished Updating Workbook")
# Out:
# Finished Updating Workbook

# %%
sheets = wb.sheetnames
import seaborn as sns

sns.violinplot(data=Individual_F18_Times, palette="bright")
# sns.violinplot(data=Individual_E2_Times, palette="bright")

# %%
import matplotlib as plt
df = average_current_cell
fig, axes = plt.subplots()
ax1 = df.plot(use_index=True, y='run time',  kind='bar', ax=axes)
ax2 = df.plot(use_index=True, y='pareto', marker='D', color="C1", kind='line', ax=axes, secondary_y=True)
ax2.set_ylim([0,110])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0449de7385d0> in <module>
#       1 import matplotlib as plt
#       2 df = average_current_cell
# ----> 3 fig, axes = plt.subplots()
#       4 ax1 = df.plot(use_index=True, y='run time',  kind='bar', ax=axes)
#       5 ax2 = df.plot(use_index=True, y='pareto', marker='D', color="C1", kind='line', ax=axes, secondary_y=True)
#
# AttributeError: module 'matplotlib' has no attribute 'subplots'

# %%
import os
from openpyxl import load_workbook
import statistics

def Average(lst):
#     print ("AVERAGING", lst)
    try:
#         print ("RETURNING", sum(lst) / len(lst))
        return sum(lst) / len(lst) 
    except:
        print (lst)
        
def lstConvert(lst):
    newlst = []
    for value in lst:
        newlst.append(float(value))
    return newlst

for subdir, _, files in os.walk("/Users/akshar/Downloads/Humans in Autonomy/Aircraft Carrier Project/SensitivityAnalysisSpreadSheets"):
    for file in files:
        if file.endswith(".xlsx"):
            print ("CURRENTLY ON " + file)
            input_workbook = subdir + os.sep + file

            wb = load_workbook(input_workbook)
            sheets = []

            for sheet in wb.worksheets:
                sheets.append(sheet)
                
            F18_Averages = []
            E2_Averages = []
            All_Averages = []
            F18_StdDevs = []
            E2_StdDevs = []
            AC_to_Person_unexpected_violations = []
            AC_to_AC_unexpected_violations = []
            F18_Halo_Violations = []
            E2_Halo_Violations = []
            All_Brown_Halo_Violations = []
            All_Blue_Halo_Violations = []
            All_White_Halo_Violations = []
            All_Green_Halo_Violations = []
            All_Red_Halo_Violations = []
            All_Purple_Halo_Violations = []
            All_Yellow_Halo_Violations = []
            Individual_F18_Times = []
            Individual_E2_Times = []

            for current_sheet in sheets[1:-1]:
                F18_Times = []
                E2_Times = []
                ac_to_person_violations = 0
                ac_to_ac_violations = 0
                F18_halo_violations = 0
                E2_halo_violations = 0
                Brown_Halo_Violations = 0
                Blue_Halo_Violations = 0
                White_Halo_Violations = 0
                Green_Halo_Violations = 0
                Red_Halo_Violations = 0
                Purple_Halo_Violations = 0
                Yellow_Halo_Violations = 0

                print ("currently on ", current_sheet)
                ws = current_sheet
                for row in ws.iter_rows(min_row=2, min_col=2, max_row=400, max_col=4):
            #         print ("PRINTING CELL")
            #         for cell in row:
            #             print (cell.value, end = " ")
            #         print ("ROW VALUE", row)
            #         if isinstance(row[1].value, float) or isinstance(row[1].value, int):
            #             print ("IF STATEMENT CHECK" + row[0].value[0])
            #             try:
            #                 if row[0].value[0] == "F":
            #                     print ("Appending {} to F18".format(row[1].value))
            #                     F18_Times.append(row[1].value)
            #                     Individual_F18_Times.append(row[1].value)
            #                 if row[0].value[0] == "E":
            #                     print ("Appending {} to E2".format(row[1].value))
            #                     E2_Times.append(row[1].value)
            #                     Individual_E2_Times.append(row[1].value)
            #             except:
            #                 print ("skipping ", row[0].value)
                    if row[2].value and isinstance(row[2].value, str) and "Expected" not in row[2].value and "ACtoAC" not in row[2].value:
                        ac_to_person_violations += 1
                        if isinstance(row[1].value, str):
                            if "D" in row[1].value:
                                Yellow_Halo_Violations += 1
                            if "CnC" in row[1].value:
                                Blue_Halo_Violations += 1
                            if "B" in row[1].value:
                                Brown_Halo_Violations += 1
                            if "W" in row[1].value:
                                White_Halo_Violations += 1
                            if "G" in row[1].value:
                                Green_Halo_Violations += 1
                            if "R" in row[1].value:
                                Red_Halo_Violations += 1
                            if "P" in row[1].value:
                                Purple_Halo_Violations += 1
                    if row[2].value and isinstance(row[2].value, str) and "ACtoAC" in row[2].value:
                        ac_to_ac_violations += 1
                        if row[0].value[0] == "F":
                            F18_halo_violations += 1
                        if row[0].value[0] == "E":
                            E2_halo_violations += 1

                for row in ws.iter_rows(min_row=2, min_col=1, max_row=400, max_col=4):
                    if row[0].value == 3:
                        try:
                            if row[1].value[0] == "F":
#                                 print ("Appending {} to F18".format(row[2].value))
                                F18_Times.append(row[2].value)
                                Individual_F18_Times.append(row[2].value)
                            if row[1].value[0] == "E":
#                                 print ("Appending {} to E2".format(row[2].value))
                                E2_Times.append(row[2].value)
                                Individual_E2_Times.append(row[2].value)
                        except:
                            print ("skipping ", row[0].value)

#                 print ("TIMES", F18_Times, E2_Times)
#                 print ("AVERAGES", F18_Averages, E2_Averages)

                F18_Averages.append((current_sheet, Average(F18_Times)))
                E2_Averages.append((current_sheet, Average(E2_Times)))
                All_Averages.append((current_sheet, (Average(F18_Times) + Average(E2_Times))/2))
                F18_StdDevs.append((current_sheet, statistics.stdev(lstConvert(F18_Times))))
                try:
                    E2_StdDevs.append((current_sheet, statistics.stdev(lstConvert(E2_Times))))
                except:
                    E2_StdDevs.append((current_sheet, E2_Times[0]))
                AC_to_Person_unexpected_violations.append((current_sheet, ac_to_person_violations))
                AC_to_AC_unexpected_violations.append((current_sheet, ac_to_ac_violations))
                F18_Halo_Violations.append((current_sheet, F18_halo_violations))
                E2_Halo_Violations.append((current_sheet, E2_halo_violations))
                All_Yellow_Halo_Violations.append((current_sheet, Yellow_Halo_Violations))
                All_Blue_Halo_Violations.append((current_sheet, Blue_Halo_Violations))
                All_Brown_Halo_Violations.append((current_sheet, Brown_Halo_Violations))
                All_White_Halo_Violations.append((current_sheet, White_Halo_Violations))
                All_Green_Halo_Violations.append((current_sheet, Green_Halo_Violations))
                All_Red_Halo_Violations.append((current_sheet, Red_Halo_Violations))
                All_Purple_Halo_Violations.append((current_sheet, Purple_Halo_Violations))
                
            aggregate = sheets[-1]
            for index in range(len(All_Averages)):
                average_current_cell = aggregate.cell(row=index+2, column=3)
                F18_current_cell = aggregate.cell(row=index+2, column=4)
                E2_current_cell = aggregate.cell(row=index+2, column=5)
                F18_stdDev_cell = aggregate.cell(row=index+2, column=6)
                E2_stdDev_cell = aggregate.cell(row=index+2, column=7)
                total_ac_to_ac_violations_cell = aggregate.cell(row=index+2, column=8)
                F18_unexpected_violations = aggregate.cell(row=index+2, column=9)
                E2_unexpected_violations = aggregate.cell(row=index+2, column=10)
                total_ac_to_person_violations_cell = aggregate.cell(row=index+2, column=11)
                All_Brown_Halo_Violations_cell = aggregate.cell(row=index+2, column=12)
                All_Blue_Halo_Violations_cell = aggregate.cell(row=index+2, column=13)
                All_White_Halo_Violations_cell = aggregate.cell(row=index+2, column=14)
                All_Green_Halo_Violations_cell = aggregate.cell(row=index+2, column=15)
                All_Red_Halo_Violations_cell = aggregate.cell(row=index+2, column=16)
                All_Purple_Halo_Violations_cell = aggregate.cell(row=index+2, column=17)
                All_Yellow_Halo_Violations_cell = aggregate.cell(row=index+2, column=18)
                try:
                    average_current_cell.value = All_Averages[index][1]
                except:
                    print (index, All_Averages, len(All_Averages), len(All_Blue_Halo_Violations))
                    print ("Could not add index " , index)
                F18_current_cell.value = F18_Averages[index][1]
                E2_current_cell.value = E2_Averages[index][1]
                F18_stdDev_cell.value = F18_StdDevs[index][1]
                E2_stdDev_cell.value = E2_StdDevs[index][1]
                total_ac_to_ac_violations_cell.value = AC_to_AC_unexpected_violations[index][1]
                F18_unexpected_violations.value = F18_Halo_Violations[index][1]
                E2_unexpected_violations.value = E2_Halo_Violations[index][1]
                total_ac_to_person_violations_cell.value = AC_to_Person_unexpected_violations[index][1]
                All_Brown_Halo_Violations_cell.value = All_Brown_Halo_Violations[index][1]
                All_Blue_Halo_Violations_cell.value = All_Blue_Halo_Violations[index][1]
                All_White_Halo_Violations_cell.value = All_White_Halo_Violations[index][1]
                All_Green_Halo_Violations_cell.value = All_Green_Halo_Violations[index][1]
                All_Red_Halo_Violations_cell.value = All_Red_Halo_Violations[index][1]
                All_Purple_Halo_Violations_cell.value = All_Purple_Halo_Violations[index][1]
                All_Yellow_Halo_Violations_cell.value = All_Yellow_Halo_Violations[index][1]

            wb.save(input_workbook)
            print ("Finished Updating Workbook")
# Out:
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_+10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 31.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_+50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_+10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_+10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_+50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime15 aircraft 13_2_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime10 aircraft 9_1_+50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime25 aircraft 21_4_+50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON OrdinanceArmTime20 aircraft 17_3_+10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime20 Aircraft 17_3_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime25 Aircraft 21_4_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime10 Aircraft 9_1_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime25 Aircraft 21_4_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime15 Aircraft 13_2_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime25 Aircraft 21_4_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON WeightCheckTime15 Aircraft 13_2_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# ...
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime20 Aircraft 17_3_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime10 Aircraft 9_1_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime10 Aircraft 9_1_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime15 Aircraft 13_2_+50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime10 Aircraft 9_1_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime25 Aircraft 21_4_-75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime15 Aircraft 13_2_-20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime15 Aircraft 13_2_+10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime25 Aircraft 21_4_+20%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime25 Aircraft 21_4_-10%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime15 Aircraft 13_2_+75%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
# CURRENTLY ON HoldbackBarTime20 Aircraft 17_3_-50%.xlsx
# currently on  <Worksheet "Run 10.csv">
# currently on  <Worksheet "Run 11.csv">
# currently on  <Worksheet "Run 13.csv">
# currently on  <Worksheet "Run 12.csv">
# currently on  <Worksheet "Run 16.csv">
# currently on  <Worksheet "Run 17.csv">
# currently on  <Worksheet "Run 15.csv">
# currently on  <Worksheet "Run 29.csv">
# currently on  <Worksheet "Run 28.csv">
# currently on  <Worksheet "Run 14.csv">
# currently on  <Worksheet "Run 9.csv">
# currently on  <Worksheet "Run 8.csv">
# currently on  <Worksheet "Run 5.csv">
# currently on  <Worksheet "Run 4.csv">
# currently on  <Worksheet "Run 6.csv">
# currently on  <Worksheet "Run 7.csv">
# currently on  <Worksheet "Run 3.csv">
# currently on  <Worksheet "Run 2.csv">
# currently on  <Worksheet "Run 1.csv">
# currently on  <Worksheet "Run 19.csv">
# currently on  <Worksheet "Run 25.csv">
# currently on  <Worksheet "Run 24.csv">
# currently on  <Worksheet "Run 30.csv">
# currently on  <Worksheet "Run 18.csv">
# currently on  <Worksheet "Run 26.csv">
# currently on  <Worksheet "Run 27.csv">
# currently on  <Worksheet "Run 23.csv">
# currently on  <Worksheet "Run 22.csv">
# currently on  <Worksheet "Run 20.csv">
# currently on  <Worksheet "Run 21.csv">
# Finished Updating Workbook
